# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalKhalane25/Python_Practices-/blob/main/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#identation

if 10<20: #condition is true
  print("My name is Komal")
# Out:
# My name is Komal

# %%
if 10>20:  #condition is false
  print("My name is Komal")

# %%
if True:
  print("My name is Komal")
# Out:
# My name is Komal

# %%
#else

if 10>20:
  print("My name is Komal")
else:
  print("I am here to teach you")
# Out:
# I am here to teach you

# %%
if 10<20:
  print("My name is Komal")
else:
  print("I am here to teach you")
# Out:
# My name is Komal

# %%
num = int(input("Enter a Number: "))

if num % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter a Number: 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-3122984957.py in <cell line: 0>()
# ----> 1 num = int(input("Enter a Number: "))
#       2
#       3 if num % 2 == 0:
#       4     print("Number is Even")
#       5 else:
#
# TypeError: 'str' object is not callable

# %%
if 500:  #500 is valid value that's whay it is true considering in programming language
  print("My name is Komal")
  print("I am here to learn python")
else:
  print("I am currently living in Dhule")
# Out:
# My name is Komal
# I am here to learn python

# %%
if 0:  #0 is  not valid value that's whay it is false considering in programming language
  print("My name is Komal")
  print("I am here to learning python")
else:
  print("I am currently living in Dhule")
# Out:
# I am currently living in Dhule

# %%
if 10>20 and 10<20:
  print("My name is Komal")
else:
  print("I am here to teach you")
# Out:
# I am here to teach you

# %%
if 10>20 or 10<20:
  print("My name is Komal")
else:
  print("I am here to teach you")
# Out:
# My name is Komal

# %%
if "komal":
  print("true")
else:
  print("false")
# Out:
# true

# %%
if "": #Not Space
  print("true")
else:
  print("false")
# Out:
# false

# %%
if " ": #space
  print("true")
else:
  print("false")
# Out:
# true

# %%
if ["komal"]:
  print("true")
else:
  print("false")
# Out:
# true

# %%
if 10>20:
  print("Python")
elif 10<20:
  print("Data Science")
else:
  print("Not Course")
# Out:
# Data Science

# %%
if 30>20:
  print("Python")
elif 10<20:
  print("Data Science")
else:
  print("Not Course")
# Out:
# Python

# %%
if 10>20:
  print("Python")
elif 10<10:
  print("Data Science")
else:
  print("Not Course")
# Out:
# Not Course

# %%
#nested if else

# %%
if 10<20:
  if 30>10:
    print("Python")
  else:
    print("Data Science")
else:
  print("Not Course")
# Out:
# Python

# %%
if 10>20:
  if 30>10:
    print("Python")
  else:
    print("Data Science")
else:
  print("Not Course")
# Out:
# Not Course

# %%
marks= int(input("Enter your marks: "))
if marks>=90:
  print("Grade A+")
elif marks>=80 and marks<=89 :
  print("Grade A")
elif marks>=70 and marks<80:
  print("Grade B")
elif 60<=marks<70:
  print("Grade C")
elif 50<=marks<60:
  print("Grade D")
else:
  print("Fail")
# Out:
# Enter your marks: 95
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-40-2563616503.py in <cell line: 0>()
# ----> 1 marks= int(input("Enter your marks: "))
#       2 if marks>90:
#       3   print("Grade A+")
#       4 elif marks>90 and marks>80 :
#       5   print("Grade A")
#
# TypeError: 'str' object is not callable
