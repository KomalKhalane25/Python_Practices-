# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalKhalane25/Python_Practices-/blob/main/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are various modes in file handling:
# 1. read only -'r'
# 2. write only -'w'
# 3. read and write both - 'r+' and 'w+'
# 4. Overwrite -'w'
# 5. Append mode - 'a' and 'a+'

# %%
myfile = open('/content/myfile.txt')

# %%
myfile.read()
# Out:
# "Hii! \nI'm Komal khalane "

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# "Hii! \nI'm Komal khalane "

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(6)
# Out:
# 6

# %%
myfile.read()
# Out:
# "\nI'm Komal khalane "

# %%
myfile.write()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-228400505.py in <cell line: 0>()
# ----> 1 myfile.write()
#
# TypeError: TextIOWrapper.write() takes exactly one argument (0 given)

# %%
myfile.close()

# %%
myfile = open('/content/myfile.txt','w')

# %%
myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipython-input-1141161747.py in <cell line: 0>()
# ----> 1 myfile.read()
#
# UnsupportedOperation: not readable

# %%
myfile.write('I am learnig here to python')
# Out:
# 27

# %%
myfile.close()

# %%
myfile = open('/content/test.txt','w')
myfile.write('I am learnig here to python')
# Out:
# 27

# %%
myfile.close()

# %%
myfile.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1141161747.py in <cell line: 0>()
# ----> 1 myfile.read()
#
# ValueError: I/O operation on closed file.

# %%
myfile = open('/content/test.txt','r+')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2053446559.py in <cell line: 0>()
# ----> 1 myfile = open('/content/test.txt','r+')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test.txt'

# %%
myfile = open('/content/test.txt','w+')

# %%
myfile.write('I am learnig here to python')
# Out:
# 27

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'I am learnig here to python'

# %%
myfile.close()

# %%
myfile = open('/content/test.txt','a')

# %%
myfile.write('\nI am learnig here to DS')
# Out:
# 24

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipython-input-1141161747.py in <cell line: 0>()
# ----> 1 myfile.read()
#
# UnsupportedOperation: not readable

# %%
myfile.close()

# %%
myfile = open('/content/test.txt','a+')

# %%
myfile.write('\nI am komal k')
# Out:
# 13

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'I am learnig here to python\nI am learnig here to DS\nI am komal k'

# %%
myfile.close()
