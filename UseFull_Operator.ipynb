# %% [markdown]
# <a href="https://colab.research.google.com/github/KomalKhalane25/Python_Practices-/blob/main/UseFull_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# in operator

'x' in ['x','y','z']
# Out:
# True

# %%
'a' in "My name is komal"
# Out:
# True

# %%
'a' in "My nAme is komAl"
# Out:
# False

# %%
10 in range(1,10)
# Out:
# False

# %%
s = "My Name is Komal Khalane"

count=0
for i in s:
    if i=='a':
     count = count+1
print(count)
# Out:
# 4

# %%
s = "My Name is Komal Khalane"
count = 0
i = 0
while i<len(s):
    if s[i]=='a':
        count = count+1
    i = i+1
print(count)
# Out:
# 4

# %%
s = "My Name is Komal Khalane"
s.count('a')
# Out:
# 4

# %%
1 in 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-21-772012422.py in <cell line: 0>()
# ----> 1 1 in 123
#
# TypeError: argument of type 'int' is not iterable

# %%
#zip()
lst1 = [1,2,3,4,5,6]
lst2 = ['a','b','c','d','e']
zip(lst1,lst2)

# %%
lst1 = [1,2,3,4,5,6]
lst2 = ['a','b','c','d','e']
list(zip(lst1,lst2))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]

# %%
tuple(zip(lst2,lst1))
# Out:
# (('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5))

# %%
set(zip(lst1,lst2))
# Out:
# {(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')}
